# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
trainset=pd.read_csv('dutch-energy.csv', sep=',')
print(trainset.columns)
# Out:
# Index(['MTU', 'Biomass', 'Fossil Brown coal/Lignite',
#        'Fossil Coal-derived gas', 'Fossil Gas', 'Fossil Hard coal',
#        'Fossil Oil', 'Fossil Oil shale', 'Fossil Peat', 'Geothermal',
#        'Hydro Pumped Storage', 'Hydro Pumped Storage.1',
#        'Hydro Run-of-river and poundage', 'Hydro Water Reservoir', 'Marine',
#        'Nuclear', 'Other', 'Other renewable', 'Solar', 'Waste',
#        'Wind Offshore', 'Wind Onshore'],
#       dtype='object')

# %%
trainset=pd.read_csv('dutch-energy.csv', sep=',').drop(['Biomass', 'Fossil Brown coal/Lignite',
       'Fossil Coal-derived gas', 'Fossil Hard coal',
       'Fossil Oil', 'Fossil Oil shale', 'Fossil Peat', 'Geothermal',
       'Hydro Pumped Storage', 'Hydro Pumped Storage.1',
       'Hydro Run-of-river and poundage', 'Hydro Water Reservoir', 'Marine',
       'Nuclear', 'Other', 'Other renewable', 'Solar', 'Waste',
       'Wind Offshore', 'Wind Onshore'],axis=1)
trainset['MTU']=pd.to_datetime(trainset['MTU'], )
#trainset=trainset.set_index('Date')[:-1]
trainset
# Out:
#                       MTU  Fossil Gas
# 0     2022-08-04 00:15:00      5613.0
# 1     2022-08-04 00:30:00      5425.0
# 2     2022-08-04 00:45:00      5039.0
# 3     2022-08-04 01:00:00      4661.0
# 4     2022-08-04 01:15:00      3833.0
# ...                   ...         ...
# 57407 2024-04-22 23:00:00      6444.0
# 57408 2024-04-22 23:15:00      6469.0
# 57409 2024-04-22 23:30:00      6420.0
# 57410 2024-04-22 23:45:00      6405.0
# 57411 2024-04-22 00:00:00      6361.0
#
# [57412 rows x 2 columns]

# %%
testset=trainset.iloc[-50:]
testset
# Out:
#                       MTU  Fossil Gas
# 57362 2024-04-22 11:45:00      3090.0
# 57363 2024-04-22 12:00:00      2858.0
# 57364 2024-04-22 12:15:00      3037.0
# 57365 2024-04-22 12:30:00      3358.0
# 57366 2024-04-22 12:45:00      3114.0
# 57367 2024-04-22 13:00:00      2917.0
# 57368 2024-04-22 13:15:00      2981.0
# 57369 2024-04-22 13:30:00      3024.0
# 57370 2024-04-22 13:45:00      2948.0
# 57371 2024-04-22 14:00:00      2815.0
# 57372 2024-04-22 14:15:00      2947.0
# 57373 2024-04-22 14:30:00      2992.0
# 57374 2024-04-22 14:45:00      2891.0
# 57375 2024-04-22 15:00:00      2827.0
# 57376 2024-04-22 15:15:00      2769.0
# 57377 2024-04-22 15:30:00      2751.0
# 57378 2024-04-22 15:45:00      2726.0
# 57379 2024-04-22 16:00:00      2887.0
# 57380 2024-04-22 16:15:00      3148.0
# 57381 2024-04-22 16:30:00      3290.0
# 57382 2024-04-22 16:45:00      3596.0
# 57383 2024-04-22 17:00:00      3900.0
# 57384 2024-04-22 17:15:00      4493.0
# 57385 2024-04-22 17:30:00      5034.0
# 57386 2024-04-22 17:45:00      5439.0
# 57387 2024-04-22 18:00:00      5706.0
# 57388 2024-04-22 18:15:00      5571.0
# 57389 2024-04-22 18:30:00      5835.0
# 57390 2024-04-22 18:45:00      6170.0
# 57391 2024-04-22 19:00:00      6351.0
# 57392 2024-04-22 19:15:00      5953.0
# 57393 2024-04-22 19:30:00      6180.0
# 57394 2024-04-22 19:45:00      6404.0
# 57395 2024-04-22 20:00:00      6502.0
# 57396 2024-04-22 20:15:00      6425.0
# 57397 2024-04-22 20:30:00      6408.0
# 57398 2024-04-22 20:45:00      6450.0
# 57399 2024-04-22 21:00:00      6464.0
# 57400 2024-04-22 21:15:00      6440.0
# 57401 2024-04-22 21:30:00      6449.0
# 57402 2024-04-22 21:45:00      6410.0
# 57403 2024-04-22 22:00:00      6322.0
# 57404 2024-04-22 22:15:00      6421.0
# 57405 2024-04-22 22:30:00      6504.0
# 57406 2024-04-22 22:45:00      6484.0
# 57407 2024-04-22 23:00:00      6444.0
# 57408 2024-04-22 23:15:00      6469.0
# 57409 2024-04-22 23:30:00      6420.0
# 57410 2024-04-22 23:45:00      6405.0
# 57411 2024-04-22 00:00:00      6361.0

# %%
trainset=trainset.iloc[:-50]
trainset
# Out:
#                       MTU  Fossil Gas
# 0     2022-08-04 00:15:00      5613.0
# 1     2022-08-04 00:30:00      5425.0
# 2     2022-08-04 00:45:00      5039.0
# 3     2022-08-04 01:00:00      4661.0
# 4     2022-08-04 01:15:00      3833.0
# ...                   ...         ...
# 57357 2024-04-22 10:30:00      3606.0
# 57358 2024-04-22 10:45:00      3355.0
# 57359 2024-04-22 11:00:00      3069.0
# 57360 2024-04-22 11:15:00      3064.0
# 57361 2024-04-22 11:30:00      3023.0
#
# [57362 rows x 2 columns]

# %%
trainset['MTU'] = pd.to_datetime(trainset['MTU'])  # Ensure MTU is in datetime format
trainset.set_index('MTU', inplace=True)            # Set MTU as the DataFrame index
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\rouss\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\indexes\base.py:3361, in Index.get_loc(self, key, method, tolerance)
#    3360 try:
# -> 3361     return self._engine.get_loc(casted_key)
#    3362 except KeyError as err:
#
# File c:\Users\rouss\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\_libs\index.pyx:76, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\rouss\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\_libs\index.pyx:108, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'MTU'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 trainset['MTU'] = pd.to_datetime(trainset['MTU'])  # Ensure MTU is in datetime format
#       2 trainset.set_index('MTU', inplace=True)            # Set MTU as the DataFrame index
#       5 trainset_hourly = trainset.resample('H').mean()  # 'H' means hourly
#
# File c:\Users\rouss\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\frame.py:3455, in DataFrame.__getitem__(self, key)
#    3453 if self.columns.nlevels > 1:
#    3454     return self._getitem_multilevel(key)
# -> 3455 indexer = self.columns.get_loc(key)
#    3456 if is_integer(indexer):
#    3457     indexer = [indexer]
#
# File c:\Users\rouss\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\indexes\base.py:3363, in Index.get_loc(self, key, method, tolerance)
#    3361         return self._engine.get_loc(casted_key)
#    3362     except KeyError as err:
# -> 3363         raise KeyError(key) from err
#    3365 if is_scalar(key) and isna(key) and not self.hasnans:
#    3366     raise KeyError(key)
#
# KeyError: 'MTU'

# %%
trainset_hourly = trainset.resample('H').mean()  # 'H' means hourly
trainset_daily = trainset.resample('D').mean()  # 'D' means daily
trainset_weekly=trainset.resample('W').mean()
trainset_monthly=trainset.resample('M').mean()
trainset_yearly = trainset.resample('Y').mean()

# %%
fig,ax = plt.subplots(nrows=1,ncols=3,figsize=(20,6))
trainset.plot(ax=ax[0],title='every 15 minutes')
trainset_hourly.plot(ax=ax[1],title='hourly')
trainset_daily.plot(ax=ax[2],title='daily')
# Out:
# <Axes: title={'center': 'daily'}, xlabel='MTU'>

# %%
fig,ax = plt.subplots(nrows=1,ncols=3,figsize=(20,6))
trainset_weekly.plot(ax=ax[0],title='weekly')
trainset_monthly.plot(ax=ax[1],title='monthly')
trainset_yearly.plot(ax=ax[2],title='yearly')
# Out:
# <Axes: title={'center': 'yearly'}, xlabel='MTU'>

# %%
trainset_2months = trainset.resample('2M').mean()
trainset_3months = trainset.resample('3M').mean()
trainset_6months = trainset.resample('6M').mean()

# %%
fig,ax = plt.subplots(nrows=1,ncols=3,figsize=(20,6))
trainset_2months.plot(ax=ax[0],title='every 2 months')
trainset_3months.plot(ax=ax[1],title='every 3 months')
trainset_6months.plot(ax=ax[2],title='every 6 months')
# Out:
# <Axes: title={'center': 'every 6 months'}, xlabel='MTU'>

# %%
print("hello")
